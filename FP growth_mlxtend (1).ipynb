# %% [markdown]
# # We will be using fpgrowth algorithm from package ----mlxtend---

# %%
#It is tree based algorithm.
#It used DFS
#Space used is linealy dependent on data.
#Scans the database twise before coming to conclusion.

# %%
# Importing all necessary packages for apriori algorithm
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
data=pd.read_csv('Online Retail.csv',encoding= 'unicode_escape')
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#As Description has many null values we will drop all those values

# %%
data.shape
# Out:
# (541909, 9)

# %%
data1=data.dropna()

# %%
# We will be dividing date into month,day and year

# %%
data1.InvoiceDate=data1.InvoiceDate.astype('str')
# Out:
# C:\Users\SU20122657.GPN\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py:4405: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
data['Month']=0

# %%
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country  Month
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom      0
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom      0
# ...

# %%
data1['year'] = pd.DatetimeIndex(data1['InvoiceDate']).year
# Out:
# C:\Users\SU20122657.GPN\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data1['Month'] = pd.DatetimeIndex(data1['InvoiceDate']).month
# Out:
# C:\Users\SU20122657.GPN\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data1['Day'] = pd.DatetimeIndex(data1['InvoiceDate']).day
# Out:
# C:\Users\SU20122657.GPN\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data1.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#       InvoiceDate  UnitPrice  CustomerID         Country  year  Month  Day
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom  2010     12    1
# ...

# %%
data1=data1.drop('InvoiceDate',axis=1)

# %%
data1.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice  CustomerID         Country  year  Month  Day
# 0       2.55     17850.0  United Kingdom  2010     12    1
# 1       3.39     17850.0  United Kingdom  2010     12    1
# 2       2.75     17850.0  United Kingdom  2010     12    1
# 3       3.39     17850.0  United Kingdom  2010     12    1
# 4       3.39     17850.0  United Kingdom  2010     12    1

# %%
#Creating new column for Total amount spend by one customer
data1['Amount_spent']=data1['Quantity']*data1['UnitPrice']

# %%
data1.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#    UnitPrice  CustomerID         Country  year  Month  Day  Amount_spent
# 0       2.55     17850.0  United Kingdom  2010     12    1         15.30
# 1       3.39     17850.0  United Kingdom  2010     12    1         20.34
# 2       2.75     17850.0  United Kingdom  2010     12    1         22.00
# 3       3.39     17850.0  United Kingdom  2010     12    1         20.34
# 4       3.39     17850.0  United Kingdom  2010     12    1         20.34

# %%
data1['Amount_spent'].describe()
# Out:
# count    406829.000000
# mean         20.401854
# std         427.591718
# min     -168469.600000
# 25%           4.200000
# 50%          11.100000
# 75%          19.500000
# max      168469.600000
# Name: Amount_spent, dtype: float64

# %%
#Here we can see we have some Amount spent values in negative.We need to remove all those

# %%
#deleting negative values
data1.Amount_spent.astype('float')
indexNames = data1[ data1['Amount_spent'] <0.0 ].index
 
# Delete these row indexes from dataFrame
data1.drop(indexNames , inplace=True)

# %%
data1['Amount_spent'].describe()
# Out:
# count    397924.000000
# mean         22.394749
# std         309.055588
# min           0.000000
# 25%           4.680000
# 50%          11.800000
# 75%          19.800000
# max      168469.600000
# Name: Amount_spent, dtype: float64

# %%
#Making invoiceNo as index and all columns describe one item in the dataset
#Filled all the empty space with 0
basket=(data1[data1['Country']=='United Kingdom'].groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('InvoiceNo'))

# %%
basket
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                  0.0                             0.0
# 536366                                  0.0                             0.0
# 536367                                  0.0                             0.0
# 536368                                  0.0                             0.0
# 536369                                  0.0                             0.0
# 536371                                  0.0                             0.0
# 536372                                  0.0                             0.0
# 536373                                  0.0                             0.0
# 536374                                  0.0                             0.0
# 536375                                  0.0                             0.0
# 536376                                  0.0                             0.0
# ...

# %%
basket_sets=basket.astype(int)

# %%
basket_sets=basket_sets.astype(bool)

# %%
basket_sets
# Out:
# Description   4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# InvoiceNo
# 536365                                False                           False
# 536366                                False                           False
# 536367                                False                           False
# 536368                                False                           False
# 536369                                False                           False
# 536371                                False                           False
# 536372                                False                           False
# 536373                                False                           False
# 536374                                False                           False
# 536375                                False                           False
# 536376                                False                           False
# ...

# %%
#!pip install --no-binary :all: mlxtend

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
frequent_itemsets=fpgrowth(basket_sets, min_support=0.03, use_colnames=True)
rules=association_rules(frequent_itemsets,metric='confidence',min_threshold=0.01)
rules.head()
# Out:
#                  antecedents                consequents  antecedent support  \
# 0  (JUMBO BAG RED RETROSPOT)  (JUMBO BAG PINK POLKADOT)            0.086912
# 1  (JUMBO BAG PINK POLKADOT)  (JUMBO BAG RED RETROSPOT)            0.048772
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.048772  0.030392    0.349689  7.169917  0.026153    1.462728
# 1            0.086912  0.030392    0.623153  7.169917  0.026153    2.422965

# %%
#By decresing min_support values we will get more and more values.

# %%
#It works on DFS that is why it is faster then apriori.
#Its accuracy can be little less due to DFS.
